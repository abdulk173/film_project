# %%
import numpy as np 
import pandas as pd

# %%
customer = pd.read_csv("A_customer.csv")
film = pd.read_csv("A_film_revenue.csv")
geo = pd.read_csv("A_geography.csv")
inventory = pd.read_csv("AAA.csv")
staff = pd.read_csv("A_staff.csv")
time = pd.read_csv("A_time_base.csv")

# %%
M1 = pd.merge(
    customer[["store_id","city_id","full_name", "country", "city", "total_amount_spent","total_number_of_rentals"]],
    staff[["store_id", "staff_id","staff_name"]],
    on = "store_id",
    how = "inner"
)
M1
# Out:
#      store_id  city_id        full_name         country                 city  \
# 0           1      442     Eleanor Hunt          Runion          Saint-Denis
# 1           2      101        Karl Seal   United States           Cape Coral
# 2           2      456    Marion Snyder          Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy     Netherlands            Apeldoorn
# 4           1      340       Clara Shaw         Belarus            Molodetno
# ..        ...      ...              ...             ...                  ...
# 594         2      159   Tiffany Jordan           China                Enshi
# 595         2      516   Anthony Schwab  American Samoa               Tafuna
# 596         1      520  Caroline Bowman   United States          Tallahassee
# 597         2      175     Leona Obrien           China               Fuzhou
# 598         1       97      Brian Wyman          Poland            Bydgoszcz
#
#      total_amount_spent  total_number_of_rentals  staff_id    staff_name
# 0                211.55                       45         1  Mike Hillyer
# 1                208.58                       42         2  Jon Stephens
# 2                194.61                       39         2  Jon Stephens
# 3                191.62                       38         2  Jon Stephens
# 4                189.60                       40         1  Mike Hillyer
# ..                  ...                      ...       ...           ...
# 594               49.88                       12         2  Jon Stephens
# 595               47.85                       15         2  Jon Stephens
# 596               37.87                       13         1  Mike Hillyer
# 597               32.90                       10         2  Jon Stephens
# 598               27.93                        7         1  Mike Hillyer
#
# [599 rows x 9 columns]

# %%
M1 = M1.rename(
    columns={
        "full_name": "customer_name",
        "country": "customer_country",
        "city": "customer_city",
        "total_amount_spent": "amount_spent_by_customer",
        "total_number_of_rentals": "number_rent_by_customer"
    }
)

M1
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id    staff_name
# 0                      211.55                       45         1  Mike Hillyer
# 1                      208.58                       42         2  Jon Stephens
# 2                      194.61                       39         2  Jon Stephens
# 3                      191.62                       38         2  Jon Stephens
# 4                      189.60                       40         1  Mike Hillyer
# ..                        ...                      ...       ...           ...
# 594                     49.88                       12         2  Jon Stephens
# 595                     47.85                       15         2  Jon Stephens
# 596                     37.87                       13         1  Mike Hillyer
# 597                     32.90                       10         2  Jon Stephens
# 598                     27.93                        7         1  Mike Hillyer
#
# [599 rows x 9 columns]

# %%
geo.columns
# Out:
# Index(['country_id', 'city_id', 'country', 'city', 'total_rentals',
#        'total_revenue', 'number_of_unique_customers',
#        'most_popular_film_category'],
#       dtype='str')

# %%
M1.columns
# Out:
# Index(['store_id', 'city_id', 'customer_name', 'customer_country',
#        'customer_city', 'amount_spent_by_customer', 'number_rent_by_customer',
#        'staff_id', 'staff_name'],
#       dtype='str')

# %%
M2 = pd.merge(
    M1,
    geo[['city_id','total_revenue','most_popular_film_category']],
    on = "city_id",
    how = "inner"
)

M2
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 0                      211.55                       45         1
# 1                      208.58                       42         2
# 2                      194.61                       39         2
# 3                      191.62                       38         2
# 4                      189.60                       40         1
# ..                        ...                      ...       ...
# 594                     49.88                       12         2
# 595                     47.85                       15         2
# 596                     37.87                       13         1
# 597                     32.90                       10         2
# 598                     27.93                        7         1
#
#        staff_name  total_revenue most_popular_film_category
# 0    Mike Hillyer         211.55                     Sci-Fi
# 1    Jon Stephens         208.58                  Animation
# 2    Jon Stephens         194.61                  Animation
# 3    Jon Stephens         191.62                      Games
# 4    Mike Hillyer         189.60                      Drama
# ..            ...            ...                        ...
# 594  Jon Stephens          49.88                  Animation
# 595  Jon Stephens          47.85                     Sports
# 596  Mike Hillyer          37.87                     Sci-Fi
# 597  Jon Stephens          32.90                  Animation
# 598  Mike Hillyer          27.93                     Action
#
# [599 rows x 11 columns]

# %%
M2 = M2.rename(
    columns={
        "total_revenue": "total_revenue_in_geo_area"
    }
)

M2
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 0                      211.55                       45         1
# 1                      208.58                       42         2
# 2                      194.61                       39         2
# 3                      191.62                       38         2
# 4                      189.60                       40         1
# ..                        ...                      ...       ...
# 594                     49.88                       12         2
# 595                     47.85                       15         2
# 596                     37.87                       13         1
# 597                     32.90                       10         2
# 598                     27.93                        7         1
#
#        staff_name  total_revenue_in_geo_area most_popular_film_category
# 0    Mike Hillyer                     211.55                     Sci-Fi
# 1    Jon Stephens                     208.58                  Animation
# 2    Jon Stephens                     194.61                  Animation
# 3    Jon Stephens                     191.62                      Games
# 4    Mike Hillyer                     189.60                      Drama
# ..            ...                        ...                        ...
# 594  Jon Stephens                      49.88                  Animation
# 595  Jon Stephens                      47.85                     Sports
# 596  Mike Hillyer                      37.87                     Sci-Fi
# 597  Jon Stephens                      32.90                  Animation
# 598  Mike Hillyer                      27.93                     Action
#
# [599 rows x 11 columns]

# %%
inventory.columns
# Out:
# Index(['store_id', 'film_id', 'category_id', 'film_title', 'category',
#        'inventory_count', 'total_rentals', 'total_revenue', 'last_rental_date',
#        'average_rental_duration_days'],
#       dtype='str')

# %%
inventory.shape
# Out:
# (1563, 10)

# %%
film.columns
# Out:
# Index(['film_id', 'category_id', 'film_title', 'category', 'average_price',
#        'quantity', 'total_rental_revenue', 'last_rental_date'],
#       dtype='str')

# %%
film.shape
# Out:
# (1000, 8)

# %%
M3 = pd.merge(
    film[['film_id', 'category_id', 'film_title', 'category', 'average_price',
       'quantity', 'total_rental_revenue', 'last_rental_date']],
    inventory[['film_id','store_id', 'inventory_count',
       'total_rentals', 'total_revenue',
       'average_rental_duration_days']],
    on = "film_id",
    how = "inner"
)

M3
# Out:
#       film_id  category_id         film_title     category  average_price  \
# 0           1            6   Academy Dinosaur  Documentary           0.99
# 1           1            6   Academy Dinosaur  Documentary           0.99
# 2           2           11     Ace Goldfinger       Horror           4.99
# 3           3            6   Adaptation Holes  Documentary           2.99
# 4           4           11   Affair Prejudice       Horror           2.99
# ...       ...          ...                ...          ...            ...
# 1558      998           11       Zhivago Core       Horror           0.99
# 1559      999            3  Zoolander Fiction     Children           2.99
# 1560      999            3  Zoolander Fiction     Children           2.99
# 1561     1000            5          Zorro Ark       Comedy           4.99
# 1562     1000            5          Zorro Ark       Comedy           4.99
#
#       quantity  total_rental_revenue     last_rental_date  store_id  \
# 0            6                  5.94  2006-02-15 10:07:09       1.0
# 1            6                  5.94  2006-02-15 10:07:09       2.0
# 2            3                 14.97  2006-02-15 10:07:09       2.0
# 3            7                 20.93  2006-02-15 10:07:09       2.0
# 4            5                 14.95  2006-02-15 10:07:09       1.0
# ...        ...                   ...                  ...       ...
# 1558         6                  5.94  2006-02-15 10:07:09       2.0
# 1559         5                 14.95  2006-02-15 10:07:09       2.0
# 1560         5                 14.95  2006-02-15 10:07:09       1.0
# 1561         3                 14.97  2006-02-15 10:07:09       1.0
# 1562         3                 14.97  2006-02-15 10:07:09       2.0
#
#       inventory_count  total_rentals  total_revenue  \
# 0                   4             12          18.89
# 1                   4             11          14.90
# 2                   3              7          52.93
# 3                   4             12          34.89
# 4                   4             13          49.88
# ...               ...            ...            ...
# 1558                2              9          10.93
# 1559                3             11          42.91
# 1560                2              6          23.94
# 1561                4             16         108.85
# 1562                4             15          90.87
#
#       average_rental_duration_days
# 0                             5.00
# 1                             4.99
# 2                             5.64
# 3                             3.47
# 4                             5.06
# ...                            ...
# 1558                          5.95
# 1559                          5.49
# 1560                          5.64
# 1561                          4.85
# 1562                          4.20
#
# [1563 rows x 13 columns]

# %%
M3 = M3.rename(
    columns={
        "quantity": "number_of_rental_day",
        "total_rental_revenue": "total_days_revenue"
    }
)

M3
# Out:
#       film_id  category_id         film_title     category  average_price  \
# 0           1            6   Academy Dinosaur  Documentary           0.99
# 1           1            6   Academy Dinosaur  Documentary           0.99
# 2           2           11     Ace Goldfinger       Horror           4.99
# 3           3            6   Adaptation Holes  Documentary           2.99
# 4           4           11   Affair Prejudice       Horror           2.99
# ...       ...          ...                ...          ...            ...
# 1558      998           11       Zhivago Core       Horror           0.99
# 1559      999            3  Zoolander Fiction     Children           2.99
# 1560      999            3  Zoolander Fiction     Children           2.99
# 1561     1000            5          Zorro Ark       Comedy           4.99
# 1562     1000            5          Zorro Ark       Comedy           4.99
#
#       number_of_rental_day  total_days_revenue     last_rental_date  store_id  \
# 0                        6                5.94  2006-02-15 10:07:09       1.0
# 1                        6                5.94  2006-02-15 10:07:09       2.0
# 2                        3               14.97  2006-02-15 10:07:09       2.0
# 3                        7               20.93  2006-02-15 10:07:09       2.0
# 4                        5               14.95  2006-02-15 10:07:09       1.0
# ...                    ...                 ...                  ...       ...
# 1558                     6                5.94  2006-02-15 10:07:09       2.0
# 1559                     5               14.95  2006-02-15 10:07:09       2.0
# 1560                     5               14.95  2006-02-15 10:07:09       1.0
# 1561                     3               14.97  2006-02-15 10:07:09       1.0
# 1562                     3               14.97  2006-02-15 10:07:09       2.0
#
#       inventory_count  total_rentals  total_revenue  \
# 0                   4             12          18.89
# 1                   4             11          14.90
# 2                   3              7          52.93
# 3                   4             12          34.89
# 4                   4             13          49.88
# ...               ...            ...            ...
# 1558                2              9          10.93
# 1559                3             11          42.91
# 1560                2              6          23.94
# 1561                4             16         108.85
# 1562                4             15          90.87
#
#       average_rental_duration_days
# 0                             5.00
# 1                             4.99
# 2                             5.64
# 3                             3.47
# 4                             5.06
# ...                            ...
# 1558                          5.95
# 1559                          5.49
# 1560                          5.64
# 1561                          4.85
# 1562                          4.20
#
# [1563 rows x 13 columns]

# %%
M2
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 0                      211.55                       45         1
# 1                      208.58                       42         2
# 2                      194.61                       39         2
# 3                      191.62                       38         2
# 4                      189.60                       40         1
# ..                        ...                      ...       ...
# 594                     49.88                       12         2
# 595                     47.85                       15         2
# 596                     37.87                       13         1
# 597                     32.90                       10         2
# 598                     27.93                        7         1
#
#        staff_name  total_revenue_in_geo_area most_popular_film_category
# 0    Mike Hillyer                     211.55                     Sci-Fi
# 1    Jon Stephens                     208.58                  Animation
# 2    Jon Stephens                     194.61                  Animation
# 3    Jon Stephens                     191.62                      Games
# 4    Mike Hillyer                     189.60                      Drama
# ..            ...                        ...                        ...
# 594  Jon Stephens                      49.88                  Animation
# 595  Jon Stephens                      47.85                     Sports
# 596  Mike Hillyer                      37.87                     Sci-Fi
# 597  Jon Stephens                      32.90                  Animation
# 598  Mike Hillyer                      27.93                     Action
#
# [599 rows x 11 columns]

# %%
customer_data = M2
film_data = M3

# %%
#WORING ON CUSTOMER DATA 

customer_data
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 0                      211.55                       45         1
# 1                      208.58                       42         2
# 2                      194.61                       39         2
# 3                      191.62                       38         2
# 4                      189.60                       40         1
# ..                        ...                      ...       ...
# 594                     49.88                       12         2
# 595                     47.85                       15         2
# 596                     37.87                       13         1
# 597                     32.90                       10         2
# 598                     27.93                        7         1
#
#        staff_name  total_revenue_in_geo_area most_popular_film_category
# 0    Mike Hillyer                     211.55                     Sci-Fi
# 1    Jon Stephens                     208.58                  Animation
# 2    Jon Stephens                     194.61                  Animation
# 3    Jon Stephens                     191.62                      Games
# 4    Mike Hillyer                     189.60                      Drama
# ..            ...                        ...                        ...
# 594  Jon Stephens                      49.88                  Animation
# 595  Jon Stephens                      47.85                     Sports
# 596  Mike Hillyer                      37.87                     Sci-Fi
# 597  Jon Stephens                      32.90                  Animation
# 598  Mike Hillyer                      27.93                     Action
#
# [599 rows x 11 columns]

# %%
#CLEANING BOTH DATA SET 

customer_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   store_id                    599 non-null    int64
#  1   city_id                     599 non-null    int64
#  2   customer_name               599 non-null    str
#  3   customer_country            599 non-null    str
#  4   customer_city               599 non-null    str
#  5   amount_spent_by_customer    599 non-null    float64
#  6   number_rent_by_customer     599 non-null    int64
#  7   staff_id                    599 non-null    int64
#  8   staff_name                  599 non-null    str
#  9   total_revenue_in_geo_area   599 non-null    float64
#  10  most_popular_film_category  599 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 51.6 KB

# %%
M2.isna().sum()
# Out:
# store_id                      0
# city_id                       0
# customer_name                 0
# customer_country              0
# customer_city                 0
# amount_spent_by_customer      0
# number_rent_by_customer       0
# staff_id                      0
# staff_name                    0
# total_revenue_in_geo_area     0
# most_popular_film_category    0
# dtype: int64

# %%
M2["customer_name"].unique()
# Out:
# <StringArray>
# [   'Eleanor Hunt',       'Karl Seal',   'Marion Snyder',  'Rhonda Kennedy',
#       'Clara Shaw',   'Tommy Collazo',     'Ana Bradley',     'Curtis Irby',
#      'Marcia Dean',        'Mike Way',
#  ...
#    'Johnny Turpin',      'Penny Neal',       'Jo Fowler',    'Bobbie Craig',
#     'Kirk Stclair',  'Tiffany Jordan',  'Anthony Schwab', 'Caroline Bowman',
#     'Leona Obrien',     'Brian Wyman']
# Length: 599, dtype: str

# %%
M2["customer_country"].unique()
# Out:
# <StringArray>
# [                          'Runion',                    'United States',
#                            'Brazil',                      'Netherlands',
#                           'Belarus',                             'Iran',
#                            'Canada',                      'Philippines',
#                             'India',                            'Spain',
#  ...
#                       'New Zealand',                             'Oman',
#                          'Slovakia',                          'Finland',
#                           'Tunisia',                      'Afghanistan',
#                             'Tonga', 'Saint Vincent and the Grenadines',
#                         'Lithuania',                   'American Samoa']
# Length: 108, dtype: str

# %%
M2.shape
# Out:
# (599, 11)

# %%
M2 = M2.drop_duplicates()
M2.shape
# Out:
# (599, 11)

# %%
M2
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 0                      211.55                       45         1
# 1                      208.58                       42         2
# 2                      194.61                       39         2
# 3                      191.62                       38         2
# 4                      189.60                       40         1
# ..                        ...                      ...       ...
# 594                     49.88                       12         2
# 595                     47.85                       15         2
# 596                     37.87                       13         1
# 597                     32.90                       10         2
# 598                     27.93                        7         1
#
#        staff_name  total_revenue_in_geo_area most_popular_film_category
# 0    Mike Hillyer                     211.55                     Sci-Fi
# 1    Jon Stephens                     208.58                  Animation
# 2    Jon Stephens                     194.61                  Animation
# 3    Jon Stephens                     191.62                      Games
# 4    Mike Hillyer                     189.60                      Drama
# ..            ...                        ...                        ...
# 594  Jon Stephens                      49.88                  Animation
# 595  Jon Stephens                      47.85                     Sports
# 596  Mike Hillyer                      37.87                     Sci-Fi
# 597  Jon Stephens                      32.90                  Animation
# 598  Mike Hillyer                      27.93                     Action
#
# [599 rows x 11 columns]

# %%
Q1 = M2["amount_spent_by_customer"].quantile(0.25)
Q3 = M2["amount_spent_by_customer"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = M2[
    (M2["amount_spent_by_customer"] < lower_bound) |
    (M2["amount_spent_by_customer"] > upper_bound)
]

print("Number of outliers:", len(outliers))
outliers.head()
# Out:
# Number of outliers: 12
#    store_id  city_id   customer_name customer_country        customer_city  \
# 0         1      442    Eleanor Hunt           Runion          Saint-Denis
# 1         2      101       Karl Seal    United States           Cape Coral
# 2         2      456   Marion Snyder           Brazil  Santa Brbara dOeste
# 3         2       29  Rhonda Kennedy      Netherlands            Apeldoorn
# 4         1      340      Clara Shaw          Belarus            Molodetno
#
#    amount_spent_by_customer  number_rent_by_customer  staff_id    staff_name  \
# 0                    211.55                       45         1  Mike Hillyer
# 1                    208.58                       42         2  Jon Stephens
# 2                    194.61                       39         2  Jon Stephens
# 3                    191.62                       38         2  Jon Stephens
# 4                    189.60                       40         1  Mike Hillyer
#
#    total_revenue_in_geo_area most_popular_film_category
# 0                     211.55                     Sci-Fi
# 1                     208.58                  Animation
# 2                     194.61                  Animation
# 3                     191.62                      Games
# 4                     189.60                      Drama

# %%
# Calculate Q1, Q3, and IQR
Q1 = M2['amount_spent_by_customer'].quantile(0.25)
Q3 = M2['amount_spent_by_customer'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
customer_data_no_outliers = M2[
    (M2['amount_spent_by_customer'] >= lower_bound) &
    (M2['amount_spent_by_customer'] <= upper_bound)
]

# %%
customer_data_no_outliers
# Out:
#      store_id  city_id   customer_name customer_country      customer_city  \
# 9           1      564        Mike Way            India           Valparai
# 10          2      458   Arnold Havens      Philippines         Santa Rosa
# 11          2      388     Wesley Bull            Spain   Ourense (Orense)
# 12          1      206   Gordon Allard            Yemen            Hodeida
# 13          1      523     Louis Leone      Philippines            Tanauan
# ..        ...      ...             ...              ...                ...
# 591         2      390       Jo Fowler          Nigeria                Oyo
# 592         1      563    Bobbie Craig           Mexico  Valle de Santiago
# 593         1      546    Kirk Stclair           Taiwan            Tsaotun
# 594         2      159  Tiffany Jordan            China              Enshi
# 595         2      516  Anthony Schwab   American Samoa             Tafuna
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 9                      162.67                       33         1
# 10                     161.68                       32         2
# 11                     158.65                       35         2
# 12                     157.69                       31         1
# 13                     156.66                       34         1
# ..                        ...                      ...       ...
# 591                     54.85                       15         2
# 592                     52.81                       19         1
# 593                     50.83                       17         1
# 594                     49.88                       12         2
# 595                     47.85                       15         2
#
#        staff_name  total_revenue_in_geo_area most_popular_film_category
# 9    Mike Hillyer                     162.67                    Foreign
# 10   Jon Stephens                     161.68                      Games
# 11   Jon Stephens                     158.65                      Games
# 12   Mike Hillyer                     157.69                     Action
# 13   Mike Hillyer                     156.66                  Animation
# ..            ...                        ...                        ...
# 591  Jon Stephens                      54.85                     Sci-Fi
# 592  Mike Hillyer                      52.81                     Sports
# 593  Mike Hillyer                      50.83                      Drama
# 594  Jon Stephens                      49.88                  Animation
# 595  Jon Stephens                      47.85                     Sports
#
# [587 rows x 11 columns]

# %%
df1 = customer_data_no_outliers

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 587 entries, 9 to 595
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   store_id                    587 non-null    int64
#  1   city_id                     587 non-null    int64
#  2   customer_name               587 non-null    str
#  3   customer_country            587 non-null    str
#  4   customer_city               587 non-null    str
#  5   amount_spent_by_customer    587 non-null    float64
#  6   number_rent_by_customer     587 non-null    int64
#  7   staff_id                    587 non-null    int64
#  8   staff_name                  587 non-null    str
#  9   total_revenue_in_geo_area   587 non-null    float64
#  10  most_popular_film_category  587 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 50.6 KB

# %%
#working and cleaning film data_set

M3
# Out:
#       film_id  category_id         film_title     category  average_price  \
# 0           1            6   Academy Dinosaur  Documentary           0.99
# 1           1            6   Academy Dinosaur  Documentary           0.99
# 2           2           11     Ace Goldfinger       Horror           4.99
# 3           3            6   Adaptation Holes  Documentary           2.99
# 4           4           11   Affair Prejudice       Horror           2.99
# ...       ...          ...                ...          ...            ...
# 1558      998           11       Zhivago Core       Horror           0.99
# 1559      999            3  Zoolander Fiction     Children           2.99
# 1560      999            3  Zoolander Fiction     Children           2.99
# 1561     1000            5          Zorro Ark       Comedy           4.99
# 1562     1000            5          Zorro Ark       Comedy           4.99
#
#       number_of_rental_day  total_days_revenue     last_rental_date  store_id  \
# 0                        6                5.94  2006-02-15 10:07:09       1.0
# 1                        6                5.94  2006-02-15 10:07:09       2.0
# 2                        3               14.97  2006-02-15 10:07:09       2.0
# 3                        7               20.93  2006-02-15 10:07:09       2.0
# 4                        5               14.95  2006-02-15 10:07:09       1.0
# ...                    ...                 ...                  ...       ...
# 1558                     6                5.94  2006-02-15 10:07:09       2.0
# 1559                     5               14.95  2006-02-15 10:07:09       2.0
# 1560                     5               14.95  2006-02-15 10:07:09       1.0
# 1561                     3               14.97  2006-02-15 10:07:09       1.0
# 1562                     3               14.97  2006-02-15 10:07:09       2.0
#
#       inventory_count  total_rentals  total_revenue  \
# 0                   4             12          18.89
# 1                   4             11          14.90
# 2                   3              7          52.93
# 3                   4             12          34.89
# 4                   4             13          49.88
# ...               ...            ...            ...
# 1558                2              9          10.93
# 1559                3             11          42.91
# 1560                2              6          23.94
# 1561                4             16         108.85
# 1562                4             15          90.87
#
#       average_rental_duration_days
# 0                             5.00
# 1                             4.99
# 2                             5.64
# 3                             3.47
# 4                             5.06
# ...                            ...
# 1558                          5.95
# 1559                          5.49
# 1560                          5.64
# 1561                          4.85
# 1562                          4.20
#
# [1563 rows x 13 columns]

# %%
M3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1563 entries, 0 to 1562
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   film_id                       1563 non-null   int64
#  1   category_id                   1563 non-null   int64
#  2   film_title                    1563 non-null   str
#  3   category                      1563 non-null   str
#  4   average_price                 1563 non-null   float64
#  5   number_of_rental_day          1563 non-null   int64
#  6   total_days_revenue            1563 non-null   float64
#  7   last_rental_date              1563 non-null   str
#  8   store_id                      1521 non-null   float64
#  9   inventory_count               1563 non-null   int64
#  10  total_rentals                 1563 non-null   int64
#  11  total_revenue                 1563 non-null   float64
#  12  average_rental_duration_days  1521 non-null   float64
# dtypes: float64(5), int64(5), str(3)
# memory usage: 158.9 KB

# %%
M3.isna().sum()
# Out:
# film_id                          0
# category_id                      0
# film_title                       0
# category                         0
# average_price                    0
# number_of_rental_day             0
# total_days_revenue               0
# last_rental_date                 0
# store_id                        42
# inventory_count                  0
# total_rentals                    0
# total_revenue                    0
# average_rental_duration_days    42
# dtype: int64

# %%
M3["store_id"].unique()
# Out:
# array([ 1.,  2., nan])

# %%
M3["average_rental_duration_days"].unique()
# Out:
# array([5.  , 4.99, 5.64, 3.47, 5.06, 4.33, 7.11, 5.45, 6.35, 2.86, 7.17,
#        5.04, 6.64, 4.87, 4.73, 4.3 , 5.86, 5.73, 4.7 , 4.63,  nan, 4.75,
#        5.15, 5.97, 5.1 , 5.91, 4.09, 5.43, 3.99, 5.74, 5.07, 4.05, 5.81,
#        4.83, 4.02, 6.13, 4.51, 4.11, 4.85, 4.66, 4.69, 5.53, 3.97, 4.59,
#        4.25, 5.76, 5.25, 4.47, 4.56, 5.42, 4.93, 5.4 , 4.86, 4.57, 6.53,
#        5.19, 4.77, 5.77, 6.67, 5.11, 3.79, 4.43, 5.3 , 6.06, 4.53, 5.84,
#        4.64, 3.93, 5.2 , 5.33, 4.48, 4.71, 5.02, 5.58, 4.41, 3.88, 4.46,
#        4.12, 4.97, 4.  , 6.01, 4.44, 6.33, 6.57, 5.35, 5.41, 4.58, 5.52,
#        5.05, 6.41, 5.16, 5.57, 5.29, 4.79, 3.03, 5.37, 3.45, 6.15, 5.67,
#        4.62, 4.29, 4.68, 4.15, 5.83, 5.39, 5.36, 5.98, 4.9 , 5.85, 3.86,
#        2.26, 4.52, 5.78, 4.23, 5.23, 3.54, 6.03, 5.56, 4.65, 7.53, 5.7 ,
#        4.88, 5.6 , 4.26, 5.22, 6.6 , 5.17, 4.91, 5.72, 6.24, 6.22, 4.67,
#        5.54, 3.52, 5.13, 4.31, 6.12, 6.72, 4.8 , 3.94, 7.75, 4.45, 4.96,
#        5.14, 5.12, 4.1 , 6.42, 3.85, 6.69, 6.17, 3.7 , 4.74, 6.11, 5.32,
#        5.5 , 4.98, 5.87, 7.58, 5.08, 4.2 , 6.78, 5.21, 4.32, 4.92, 3.44,
#        5.34, 3.09, 4.22, 6.26, 6.39, 5.62, 5.31, 5.88, 6.37, 3.9 , 4.01,
#        5.26, 5.28, 3.37, 5.09, 4.39, 8.02, 4.21, 4.04, 3.82, 6.51, 5.63,
#        5.66, 4.35, 4.16, 6.73, 5.27, 5.69, 5.68, 5.92, 3.62, 5.01, 3.22,
#        5.47, 2.44, 5.61, 7.45, 3.84, 7.03, 2.01, 6.28, 6.19, 4.17, 5.82,
#        6.46, 5.94, 4.34, 3.57, 4.6 , 4.94, 3.98, 3.78, 4.36, 3.4 , 4.76,
#        5.03, 1.93, 4.82, 6.09, 4.49, 6.47, 5.96, 6.29, 5.38, 6.31, 4.89,
#        5.59, 7.25, 4.18, 3.58, 3.51, 5.24, 6.  , 3.68, 4.28, 5.71, 6.36,
#        4.42, 4.95, 5.89, 5.55, 5.49, 7.27, 6.65, 5.9 , 6.18, 4.61, 6.54,
#        4.14, 2.96, 4.81, 4.03, 3.77, 4.55, 4.72, 3.89, 3.75, 4.27, 4.13,
#        6.66, 5.65, 6.63, 6.25, 5.46, 6.32, 6.81, 3.15, 6.1 , 3.63, 7.31,
#        7.18, 6.68, 5.79, 6.34, 5.8 , 6.95, 3.02, 6.04, 6.05, 7.19, 5.48,
#        6.23, 7.07, 3.16, 6.07, 6.16, 6.74, 6.14, 6.94, 3.1 , 4.4 , 7.2 ,
#        3.96, 3.39, 3.12, 3.67, 3.95, 3.69, 5.51, 3.46, 4.24, 4.38, 2.59,
#        3.29, 5.93, 3.53, 6.27, 5.75, 6.62, 3.76, 6.49, 7.63, 3.17, 6.02,
#        4.78, 5.44, 2.94, 3.64, 3.43, 6.4 , 6.3 , 3.91, 4.08, 2.49, 5.18,
#        3.8 , 4.54, 7.36, 5.95, 4.5 , 7.24, 3.92, 4.19, 2.77, 3.19, 4.07,
#        6.76, 6.55, 3.08, 3.55, 6.87, 3.  , 6.56, 3.73, 3.41, 6.58, 3.04,
#        6.21, 7.6 , 3.56, 6.71, 6.2 , 3.25, 4.37, 3.28, 7.21, 3.48, 2.65,
#        3.38, 7.1 , 6.92, 3.01, 3.14, 3.65, 6.52, 6.77, 3.34, 3.11, 3.35,
#        2.72, 3.26, 3.5 , 7.51, 3.74, 6.75, 6.88, 2.69, 3.49, 3.59, 3.36])

# %%
M3["last_rental_date"].unique()
# Out:
# <StringArray>
# ['2006-02-15 10:07:09']
# Length: 1, dtype: str
