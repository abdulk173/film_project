# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
customer = pd.read_csv("A_customer.csv")
film = pd.read_csv("A_film_revenue.csv")
geo = pd.read_csv("A_geography.csv")
inventory = pd.read_csv("AAA.csv")
staff = pd.read_csv("A_staff.csv")
time = pd.read_csv("A_time_base.csv")
full_data = pd.read_csv("best.csv")

# %%
M1 = pd.merge(
    customer[["store_id","city_id","full_name", "country", "city", "total_amount_spent","total_number_of_rentals"]],
    staff[["store_id", "staff_id","staff_name"]],
    on = "store_id",
    how = "inner"
)
M1
# Out:
#      store_id  city_id        full_name         country                 city  \
# 0           1      442     Eleanor Hunt          Runion          Saint-Denis
# 1           2      101        Karl Seal   United States           Cape Coral
# 2           2      456    Marion Snyder          Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy     Netherlands            Apeldoorn
# 4           1      340       Clara Shaw         Belarus            Molodetno
# ..        ...      ...              ...             ...                  ...
# 594         2      159   Tiffany Jordan           China                Enshi
# 595         2      516   Anthony Schwab  American Samoa               Tafuna
# 596         1      520  Caroline Bowman   United States          Tallahassee
# 597         2      175     Leona Obrien           China               Fuzhou
# 598         1       97      Brian Wyman          Poland            Bydgoszcz
#
#      total_amount_spent  total_number_of_rentals  staff_id    staff_name
# 0                211.55                       45         1  Mike Hillyer
# 1                208.58                       42         2  Jon Stephens
# 2                194.61                       39         2  Jon Stephens
# 3                191.62                       38         2  Jon Stephens
# 4                189.60                       40         1  Mike Hillyer
# ..                  ...                      ...       ...           ...
# 594               49.88                       12         2  Jon Stephens
# 595               47.85                       15         2  Jon Stephens
# 596               37.87                       13         1  Mike Hillyer
# 597               32.90                       10         2  Jon Stephens
# 598               27.93                        7         1  Mike Hillyer
#
# [599 rows x 9 columns]

# %%
M1 = M1.rename(
    columns={
        "full_name": "customer_name",
        "country": "customer_country",
        "city": "customer_city",
        "total_amount_spent": "amount_spent_by_customer",
        "total_number_of_rentals": "number_rent_by_customer"
    }
)

M1
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id    staff_name
# 0                      211.55                       45         1  Mike Hillyer
# 1                      208.58                       42         2  Jon Stephens
# 2                      194.61                       39         2  Jon Stephens
# 3                      191.62                       38         2  Jon Stephens
# 4                      189.60                       40         1  Mike Hillyer
# ..                        ...                      ...       ...           ...
# 594                     49.88                       12         2  Jon Stephens
# 595                     47.85                       15         2  Jon Stephens
# 596                     37.87                       13         1  Mike Hillyer
# 597                     32.90                       10         2  Jon Stephens
# 598                     27.93                        7         1  Mike Hillyer
#
# [599 rows x 9 columns]

# %%
geo.columns
# Out:
# Index(['country_id', 'city_id', 'country', 'city', 'total_rentals',
#        'total_revenue', 'number_of_unique_customers',
#        'most_popular_film_category'],
#       dtype='str')

# %%
M1.columns
# Out:
# Index(['store_id', 'city_id', 'customer_name', 'customer_country',
#        'customer_city', 'amount_spent_by_customer', 'number_rent_by_customer',
#        'staff_id', 'staff_name'],
#       dtype='str')

# %%
M2 = pd.merge(
    M1,
    geo[['city_id','total_revenue','most_popular_film_category']],
    on = "city_id",
    how = "inner"
)

M2
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 0                      211.55                       45         1
# 1                      208.58                       42         2
# 2                      194.61                       39         2
# 3                      191.62                       38         2
# 4                      189.60                       40         1
# ..                        ...                      ...       ...
# 594                     49.88                       12         2
# 595                     47.85                       15         2
# 596                     37.87                       13         1
# 597                     32.90                       10         2
# 598                     27.93                        7         1
#
#        staff_name  total_revenue most_popular_film_category
# 0    Mike Hillyer         211.55                     Sci-Fi
# 1    Jon Stephens         208.58                  Animation
# 2    Jon Stephens         194.61                  Animation
# 3    Jon Stephens         191.62                      Games
# 4    Mike Hillyer         189.60                      Drama
# ..            ...            ...                        ...
# 594  Jon Stephens          49.88                  Animation
# 595  Jon Stephens          47.85                     Sports
# 596  Mike Hillyer          37.87                     Sci-Fi
# 597  Jon Stephens          32.90                  Animation
# 598  Mike Hillyer          27.93                     Action
#
# [599 rows x 11 columns]

# %%
M2 = M2.rename(
    columns={
        "total_revenue": "total_revenue_in_geo_area"
    }
)

M2
# Out:
#      store_id  city_id    customer_name customer_country        customer_city  \
# 0           1      442     Eleanor Hunt           Runion          Saint-Denis
# 1           2      101        Karl Seal    United States           Cape Coral
# 2           2      456    Marion Snyder           Brazil  Santa Brbara dOeste
# 3           2       29   Rhonda Kennedy      Netherlands            Apeldoorn
# 4           1      340       Clara Shaw          Belarus            Molodetno
# ..        ...      ...              ...              ...                  ...
# 594         2      159   Tiffany Jordan            China                Enshi
# 595         2      516   Anthony Schwab   American Samoa               Tafuna
# 596         1      520  Caroline Bowman    United States          Tallahassee
# 597         2      175     Leona Obrien            China               Fuzhou
# 598         1       97      Brian Wyman           Poland            Bydgoszcz
#
#      amount_spent_by_customer  number_rent_by_customer  staff_id  \
# 0                      211.55                       45         1
# 1                      208.58                       42         2
# 2                      194.61                       39         2
# 3                      191.62                       38         2
# 4                      189.60                       40         1
# ..                        ...                      ...       ...
# 594                     49.88                       12         2
# 595                     47.85                       15         2
# 596                     37.87                       13         1
# 597                     32.90                       10         2
# 598                     27.93                        7         1
#
#        staff_name  total_revenue_in_geo_area most_popular_film_category
# 0    Mike Hillyer                     211.55                     Sci-Fi
# 1    Jon Stephens                     208.58                  Animation
# 2    Jon Stephens                     194.61                  Animation
# 3    Jon Stephens                     191.62                      Games
# 4    Mike Hillyer                     189.60                      Drama
# ..            ...                        ...                        ...
# 594  Jon Stephens                      49.88                  Animation
# 595  Jon Stephens                      47.85                     Sports
# 596  Mike Hillyer                      37.87                     Sci-Fi
# 597  Jon Stephens                      32.90                  Animation
# 598  Mike Hillyer                      27.93                     Action
#
# [599 rows x 11 columns]

# %%
inventory.columns
# Out:
# Index(['store_id', 'film_id', 'category_id', 'film_title', 'category',
#        'inventory_count', 'total_rentals', 'total_revenue', 'last_rental_date',
#        'average_rental_duration_days'],
#       dtype='str')

# %%
inventory.shape
# Out:
# (1563, 10)

# %%
film.columns
# Out:
# Index(['film_id', 'category_id', 'film_title', 'category', 'average_price',
#        'quantity', 'total_rental_revenue', 'last_rental_date'],
#       dtype='str')

# %%
film.shape
# Out:
# (1000, 8)

# %%
M3 = pd.merge(
    film[['film_id', 'category_id', 'film_title', 'category', 'average_price',
       'quantity', 'total_rental_revenue', 'last_rental_date']],
    inventory[['film_id','store_id', 'inventory_count',
       'total_rentals', 'total_revenue',
       'average_rental_duration_days']],
    on = "film_id",
    how = "inner"
)

M3
# Out:
#       film_id  category_id         film_title     category  average_price  \
# 0           1            6   Academy Dinosaur  Documentary           0.99
# 1           1            6   Academy Dinosaur  Documentary           0.99
# 2           2           11     Ace Goldfinger       Horror           4.99
# 3           3            6   Adaptation Holes  Documentary           2.99
# 4           4           11   Affair Prejudice       Horror           2.99
# ...       ...          ...                ...          ...            ...
# 1558      998           11       Zhivago Core       Horror           0.99
# 1559      999            3  Zoolander Fiction     Children           2.99
# 1560      999            3  Zoolander Fiction     Children           2.99
# 1561     1000            5          Zorro Ark       Comedy           4.99
# 1562     1000            5          Zorro Ark       Comedy           4.99
#
#       quantity  total_rental_revenue     last_rental_date  store_id  \
# 0            6                  5.94  2006-02-15 10:07:09       1.0
# 1            6                  5.94  2006-02-15 10:07:09       2.0
# 2            3                 14.97  2006-02-15 10:07:09       2.0
# 3            7                 20.93  2006-02-15 10:07:09       2.0
# 4            5                 14.95  2006-02-15 10:07:09       1.0
# ...        ...                   ...                  ...       ...
# 1558         6                  5.94  2006-02-15 10:07:09       2.0
# 1559         5                 14.95  2006-02-15 10:07:09       2.0
# 1560         5                 14.95  2006-02-15 10:07:09       1.0
# 1561         3                 14.97  2006-02-15 10:07:09       1.0
# 1562         3                 14.97  2006-02-15 10:07:09       2.0
#
#       inventory_count  total_rentals  total_revenue  \
# 0                   4             12          18.89
# 1                   4             11          14.90
# 2                   3              7          52.93
# 3                   4             12          34.89
# 4                   4             13          49.88
# ...               ...            ...            ...
# 1558                2              9          10.93
# 1559                3             11          42.91
# 1560                2              6          23.94
# 1561                4             16         108.85
# 1562                4             15          90.87
#
#       average_rental_duration_days
# 0                             5.00
# 1                             4.99
# 2                             5.64
# 3                             3.47
# 4                             5.06
# ...                            ...
# 1558                          5.95
# 1559                          5.49
# 1560                          5.64
# 1561                          4.85
# 1562                          4.20
#
# [1563 rows x 13 columns]
